# %% [markdown]
# <a href="https://colab.research.google.com/github/udupa-varun/pyimagesearch_uni/blob/main/deep_learning/105/keras_visualize_architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/keras-visualize-architecture/keras-visualize-architecture.zip
# !unzip -qq keras-visualize-architecture
# %cd keras-visualize-architecture
# Out:
# --2023-02-23 15:31:19--  https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/keras-visualize-architecture/keras-visualize-architecture.zip
# Resolving pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)... 52.218.200.153, 52.218.216.73, 52.218.244.225, ...
# Connecting to pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)|52.218.200.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 108252 (106K) [application/zip]
# Saving to: ‘keras-visualize-architecture.zip’
#
# keras-visualize-arc 100%[===================>] 105.71K  --.-KB/s    in 0.08s
#
# 2023-02-23 15:31:19 (1.23 MB/s) - ‘keras-visualize-architecture.zip’ saved [108252/108252]
#
# /content/keras-visualize-architecture

# %%
from matplotlib import pyplot as plt
from tensorflow.keras.utils import plot_model
from pyimagesearch.nn.conv import LeNet

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# init LeNet and then write network architecture viz graph to disk
model = LeNet.build(28, 28, 1, 10)
plot_model(model, to_file="lenet.png", show_shapes=True)
